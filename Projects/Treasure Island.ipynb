# %%
print('''
*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
          |                `"=._o`"=._      _`"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
          |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
 _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      `".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/_____ /
*******************************************************************************
''')
print("Welcome to Treasure Island.")
print("Your mission is to find the treasure.") 

#https://www.draw.io/?lightbox=1&highlight=0000ff&edit=_blank&layers=1&nav=1&title=Treasure%20Island%20Conditional.drawio#Uhttps%3A%2F%2Fdrive.google.com%2Fuc%3Fid%3D1oDe4ehjWZipYRsVfeAx2HyB7LCQ8_Fvi%26export%3Ddownload

#Write your code below this line 👇
print("Your boat encountered a storm and crashed upon a deserted island.")
print("You stand up and find yourself on the beach, and see a path leading into the jungle.")
print("You see a cave is the distance.  The path in front of you splits left or right.")
step1 = input("   Which way do you go? L or R. \n").lower()

if step1 == "l":
  print("You take the left path and continue through the jungle.")
  print("Ahead in the jungle you see a huge log fallen across the path.")
  print("You can climb over the log or go around.")
  step2 = input("   Which way do you choose? Over or Around. \n").lower()
  if step2 == "over":
    print("You carefully climb over the huge log and safely continue along the path.")
    print("You find the cave entrance and go inside.")
    print("Inside the cave you see three tunnels.")
    print("One if to the left(L)")
    print("Another is to the right(R)")
    print("An one is straight in front of you(S)")
    step3 = input("   Which tunnel do you take? L, R or S. \n").lower()
    if step3 == "r":
      print("You choose the right tunnel and continue on.")
      print("The tunnel leads to the treasure room.")
      print("You have found the treasure!")
      print("YOU WIN!")
    elif step3 == "l":
      print("You choose the left tunnel and continue on.")
      print("The tunnel gets very dark and you slip and fall into a hole and die.")
      print("GAME OVER")
    elif step3 =="s":
      print("You choose the tunnel straight ahead and continue on.")
      print("You hear something growl and stop.")
      print("A huge lion walks out from the dark and jumps on you")
      print("The lion eats you.")
      print("GAME OVER")
    else:
      print("You didn't choose the right path.")
      print("GAME OVER")
  else:
    print("You find away around the log and run into a nest of bees.")
    print("The bees swarm you and sting you to death.")
    print("GAME OVER")
else:
  print("You take the wrong path and fall into quicksand and die.")
  print("GAME OVER")
# Out:
# *******************************************************************************
#           |                   |                  |                     |
#  _________|________________.=""_;=.______________|_____________________|_______
# |                   |  ,-"_,=""     `"=.|                  |
# |___________________|__"=._o`"-._        `"=.______________|___________________
#           |                `"=._o`"=._      _`"=._                     |
#  _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
# |                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
# |___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
#           |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
#  _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
# |                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
# |___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
# ...
